# %% [markdown]
# Labb 2 Uppgift 1 Riket

# %%
#Src
import webbrowser
url = "https://stackoverflow.com/questions/62052628/pandas-read-excel-from-filepath"
url = "https://pandas.pydata.org/docs/user_guide/basics.html#basics-rename"
url = "https://github.com/AIgineerAB/Python_OPA24_code_along/blob/main/repeat_pandas_matplotlib.ipynb"
url = "https://www.statology.org/pandas-read-excel-column-names/"
webbrowser.open(url)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Ny dataframe för varje ämne

# %%
#Engelska
colnames = ['Plats', 'Huvudman', 'Totalt (A-F)', 'Flickor (A-F)', 'Pojkar (A-F)', 'Totalt (A-E)', 'Flickor (A-E)', 'Pojkar (A-E)', 'Totalt (poäng)', 'Flickor (poäng)', 'Pojkar (poäng)']
filepath = r"C:\\filer\riket2023_åk9_np (2).xlsx"
df = pd.read_excel(filepath, names=colnames, skiprows=8, sheet_name='Engelska')
df.head()
# Out:
#    Plats    Huvudman  Totalt (A-F)  Flickor (A-F)  Pojkar (A-F)  Totalt (A-E)  \
# 0  Riket    Samtliga        106941          51864         55077          97.0
# 1  Riket    Kommunal         84310          40675         43635          96.6
# 2  Riket     Enskild         22582          11165         11417          98.7
# 3  Riket  Skolverket            49             24            25         100.0
#
#    Flickor (A-E)  Pojkar (A-E)  Totalt (poäng)  Flickor (poäng)  \
# 0           97.1          97.0            15.7             15.8
# 1           96.6          96.6            15.4             15.5
# 2           98.8          98.7            16.9             17.0
# 3          100.0         100.0            18.5             18.9
#
#    Pojkar (poäng)
# 0            15.7
# 1            15.4
# 2            16.8
# 3            18.2

# %%
#Matematik
colnames = ['Plats', 'Huvudman', 'Totalt (A-F)', 'Flickor (A-F)', 'Pojkar (A-F)', 'Totalt (A-E)', 'Flickor (A-E)', 'Pojkar (A-E)', 'Totalt (poäng)', 'FLickor (poäng)', 'Pojkar (poäng)']
filepath = r"C:\\filer\riket2023_åk9_np (2).xlsx"
df = pd.read_excel(filepath, names=colnames, skiprows=8, sheet_name='Matematik')
df.head()
# Out:
#    Plats    Huvudman  Totalt (A-F)  Flickor (A-F)  Pojkar (A-F) Totalt (A-E)  \
# 0  Riket    Samtliga        106766          51548         55218         89.1
# 1  Riket    Kommunal         84163          40386         43777         88.1
# 2  Riket     Enskild         22553          11137         11416         92.9
# 3  Riket  Skolverket            50             25            25         ~100
#
#   Flickor (A-E) Pojkar (A-E)  Totalt (poäng)  FLickor (poäng)  Pojkar (poäng)
# 0          88.7         89.5            11.9             11.8            12.0
# 1          87.7         88.5            11.6             11.5            11.7
# 2          92.2         93.5            13.0             12.8            13.1
# 3          ~100         ~100            14.1             13.5            14.7

# %%
#Svenska
colnames = ['Plats', 'Huvudman', 'Totalt (A-F)', 'Flickor (A-F)', 'Pojkar (A-F)', 'Totalt (A-E)', 'Flickor (A-E)', 'Pojkar (A-E)', 'Totalt (poäng)', 'Flickor (poäng)', 'Pojkar (Poäng)']
filepath = r"C:\\filer\riket2023_åk9_np (2).xlsx"
df = pd.read_excel(filepath, names=colnames, skiprows=8, sheet_name='Svenska')
df.head()
# Out:
#    Plats    Huvudman  Totalt (A-F)  Flickor (A-F)  Pojkar (A-F)  Totalt (A-E)  \
# 0  Riket    Samtliga         93225          45800         47425          96.1
# 1  Riket    Kommunal         72771          35484         37287          95.7
# 2  Riket     Enskild         20414          10297         10117          97.6
# 3  Riket  Skolverket            40             19            21         100.0
#
#    Flickor (A-E)  Pojkar (A-E)  Totalt (poäng)  Flickor (poäng)  \
# 0           97.9          94.4            13.6             14.5
# 1           97.6          93.8            13.3             14.3
# 2           98.7          96.6            14.4             15.2
# 3          100.0         100.0            15.0             15.9
#
#    Pojkar (Poäng)
# 0            12.7
# 1            12.4
# 2            13.5
# 3            14.2

# %%
#Svenska som andraspråk
colnames = ['Plats', 'Huvudman', 'Totalt (A-F)', 'Flickor (A-F)', 'Pojkar (A-F)', 'Totalt (A-E)', 'Flickor (A-E)', 'Pojkar (A-E)', 'Totalt (poäng)', 'Flickor (poäng)', 'Pojkar (Poäng)']
filepath = r"C:\\filer\riket2023_åk9_np (2).xlsx"
df = pd.read_excel(filepath, names=colnames, skiprows=8, sheet_name='Svenska som andraspråk')
df.head()
# Out:
#    Plats    Huvudman Totalt (A-F) Flickor (A-F) Pojkar (A-F) Totalt (A-E)  \
# 0  Riket    Samtliga        14092          6447         7645         77.7
# 1  Riket    Kommunal        11963          5495         6468         75.9
# 2  Riket     Enskild         2122           949         1173         87.7
# 3  Riket  Skolverket           ..            ..           ..           ..
#
#   Flickor (A-E) Pojkar (A-E) Totalt (poäng) Flickor (poäng) Pojkar (Poäng)
# 0          81.6         74.3            9.4            10.2            8.7
# 1            80         72.4              9             9.9            8.3
# 2          90.9         85.2           11.1              12           10.4
# 3            ..           ..             ..              ..             ..

# %% [markdown]
# ### Plotting, totala poängen för de olika huvudmännen

# %%
filepath = r"C:\filer\riket2023_åk9_np (2).xlsx"

sheet_names = ['Engelska', 'Matematik', 'Svenska', 'Svenska som andraspråk']

colnames = ['Plats', 'Huvudman', 'Totalt (A-F)', 'Flickor (A-F)',
            'Pojkar (A-F)', 'Totalt (A-E)', 'Flickor (A-E)',
            'Pojkar (A-E)', 'Totalt (poäng)', 'Flickor (poäng)', 'Pojkar (Poäng)']

#----2x2 grid med subplottar
fig, axs = plt.subplots(2, 2, figsize=(18, 12))
fig.suptitle("Totala poängen för de olika huvudmännen", fontsize=20)

#----Flatten/Platta ut 2D array till 1D array
axs = axs.ravel()

for i, subject in enumerate(sheet_names):
    df = pd.read_excel(filepath, skiprows=8, sheet_name=subject)
    df.columns = colnames[:len(df.columns)]

    #----Använder huvudman som kategori och totalt (poäng) som värden
    kategorier = df["Huvudman"]
    values = pd.to_numeric(df["Totalt (poäng)"], errors="coerce")

    #----Här skapar jag en lista med färger som matchar kategorierna
    colors = plt.cm.Paired(np.linspace(0,1, len(kategorier)))#colormap

    #----Stapeldiagram
    ax = axs[i]
    ax.bar(kategorier, values, color=colors)
    ax.set_title(subject)
    ax.set_xlabel("Huvudman")
    ax.set_ylabel("Totalt poäng")
    ax.set_xticks(np.arange(len(kategorier)))
    ax.set_xticklabels(kategorier, rotation=45, ha="right")

    #----Justerar layout
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
